# %% [markdown]
# # Energy Demand Forecasting with Granite Timeseries (TTM)
#
# TinyTimeMixers (TTMs) are compact pre-trained models for Multivariate Time-Series Forecasting, open-sourced by IBM Research. With less than 1 Million parameters, TTM introduces the notion of the first-ever "tiny" pre-trained models for Time-Series Forecasting. TTM outperforms several popular benchmarks demanding billions of parameters in zero-shot and few-shot forecasting and can easily be fine-tuned for multi-variate forecasts.

# %% [markdown]
# ### Install the TSFM Library
#
# The [granite-tsfm library](https://github.com/ibm-granite/granite-tsfm) provides utilities for working with Time Series Foundation Models (TSFM). Here the pinned version is retrieved and installed.

# %%
# Install the tsfm library
! pip install "tsfm_public[notebooks] @ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17" -U
# Out:
# Collecting tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17 (from tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17)
#   Cloning https://github.com/ibm-granite/granite-tsfm.git (to revision v0.2.17) to /private/var/folders/5x/cztshy892cbf92p2fdgqlxhc0000gn/T/pip-install-vvimhxb2/tsfm-public_6ed3a4262e8a4dbfa72160ebc6cf0614
#   Running command git clone --filter=blob:none --quiet https://github.com/ibm-granite/granite-tsfm.git /private/var/folders/5x/cztshy892cbf92p2fdgqlxhc0000gn/T/pip-install-vvimhxb2/tsfm-public_6ed3a4262e8a4dbfa72160ebc6cf0614
#   Running command git checkout -q a1da2c54b083e1262e0e3330dcf6ef9d757d8b89
#   Resolved https://github.com/ibm-granite/granite-tsfm.git to commit a1da2c54b083e1262e0e3330dcf6ef9d757d8b89
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>=2.2.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.2.3)
# Requirement already satisfied: scikit-learn in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.6.1)
# Requirement already satisfied: transformers>=4.38.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (4.51.0)
# Requirement already satisfied: datasets in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.5.0)
# Requirement already satisfied: deprecated in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.2.18)
# Requirement already satisfied: urllib3<2,>=1.26.19 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.26.20)
# Requirement already satisfied: numpy<2 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.26.4)
# Requirement already satisfied: jupyter in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.1.1)
# Requirement already satisfied: matplotlib in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.10.1)
# Requirement already satisfied: ipywidgets in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (8.1.5)
# Requirement already satisfied: plotly in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (6.0.1)
# Requirement already satisfied: kaleido in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.2.1)
# Requirement already satisfied: tensorboard in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.19.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from pandas>=2.2.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from pandas>=2.2.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from pandas>=2.2.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2025.2)
# Requirement already satisfied: filelock in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.30.1)
# Requirement already satisfied: packaging>=20.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2024.11.6)
# Requirement already satisfied: requests in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (4.67.1)
# Requirement already satisfied: torch>=2.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.6.0)
# Requirement already satisfied: accelerate>=0.26.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.6.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.3.8)
# Requirement already satisfied: xxhash in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2024.12.0)
# Requirement already satisfied: aiohttp in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.11.16)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from deprecated->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.17.2)
# Requirement already satisfied: comm>=0.1.3 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (9.1.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.0.13)
# Requirement already satisfied: notebook in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (7.3.3)
# Requirement already satisfied: jupyter-console in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (7.16.6)
# Requirement already satisfied: ipykernel in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (6.29.5)
# Requirement already satisfied: jupyterlab in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (4.3.6)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from matplotlib->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from matplotlib->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from matplotlib->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from matplotlib->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from matplotlib->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from matplotlib->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.2.3)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from plotly->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.34.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from scikit-learn->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from scikit-learn->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from scikit-learn->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.6.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.2.2)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (6.30.2)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (65.5.0)
# Requirement already satisfied: six>1.9 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.1.3)
# Requirement already satisfied: psutil in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from accelerate>=0.26.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (7.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from aiohttp->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from aiohttp->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from aiohttp->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from aiohttp->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from aiohttp->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from aiohttp->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from aiohttp->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.19.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (4.13.1)
# Requirement already satisfied: decorator in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.19.1)
# Requirement already satisfied: stack_data in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from requests->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from requests->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from requests->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2025.1.31)
# Requirement already satisfied: networkx in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.0.2)
# Requirement already satisfied: appnope in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.8.13)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (5.7.2)
# Requirement already satisfied: nest-asyncio in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (6.4.2)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.5.1)
# Requirement already satisfied: webencodings in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.4.0)
# Requirement already satisfied: anyio in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (4.3.7)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from nbformat>=5.7->nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.2.3)
# Requirement already satisfied: sniffio>=1.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.24.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (0.1.1)
# Requirement already satisfied: fqdn in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.5.1)
# Requirement already satisfied: isoduration in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (3.0.0)
# Requirement already satisfied: uri-template in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.17.1)
# Requirement already satisfied: pycparser in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.17) (2.9.0.20241206)

# %% [markdown]
# ### Import Packages
#
# From `tsfm_public`, we use the TinyTimeMixer model, forecasting pipeline, and plotting function.

# %%
import matplotlib.pyplot as plt
import pandas as pd

from tsfm_public import (
    TimeSeriesForecastingPipeline,
    TinyTimeMixerForPrediction,
)
from tsfm_public.toolkit.visualization import plot_predictions
# Out:
# INFO:p-40371:t-8498793472:config.py:<module>:PyTorch version 2.6.0 available.

# %% [markdown]
# ### Download the data
#
# We'll work with a dataset of hourly electrical demand, generation by type, and weather in Spain. This dataset was originally available [from Kaggle](https://www.kaggle.com/datasets/nicholasjhana/energy-consumption-generation-prices-and-weather). To simplify access to the data, we will make use of the ([energy consumption](https://huggingface.co/datasets/vitaliy-sharandin/energy-consumption-hourly-spain) and [weather](https://huggingface.co/datasets/vitaliy-sharandin/energy-consumption-weather-hourly-spain)) datasets on Hugging Face.

# %%
DATA_FILE_PATH = "hf://datasets/vitaliy-sharandin/energy-consumption-hourly-spain/energy_dataset.csv"

# %% [markdown]
# ### Specify time and output variables
#
# We provide the names of the timestamp column and the target column to be predicted. The context length (in time steps) is set to match the pretrained model.

# %%
timestamp_column = "time"
target_columns = ["total load actual"]
context_length = 512

# %% [markdown]
# ### Read in the data
#
# We parse the csv into a pandas dataframe, filling in any null values, and create a single window containing `context_length` time points. We ensure the timestamp column is a datetime.

# %%
# Read in the data from the downloaded file.
input_df = pd.read_csv(
    DATA_FILE_PATH,
    parse_dates=[timestamp_column],  # Parse the timestamp values as dates.
)

# Fill NA/NaN values by propagating the last valid value.
input_df = input_df.ffill()

# Only use the last `context_length` rows for prediction.
input_df = input_df.iloc[-context_length:,]

# Show the last few rows of the dataset.
input_df.tail()
# Out:
#                             time  generation biomass  \
# 35059  2018-12-31 19:00:00+01:00               297.0
# 35060  2018-12-31 20:00:00+01:00               296.0
# 35061  2018-12-31 21:00:00+01:00               292.0
# 35062  2018-12-31 22:00:00+01:00               293.0
# 35063  2018-12-31 23:00:00+01:00               290.0
#
#        generation fossil brown coal/lignite  \
# 35059                                   0.0
# 35060                                   0.0
# 35061                                   0.0
# 35062                                   0.0
# 35063                                   0.0
#
#        generation fossil coal-derived gas  generation fossil gas  \
# 35059                                 0.0                 7634.0
# 35060                                 0.0                 7241.0
# 35061                                 0.0                 7025.0
# 35062                                 0.0                 6562.0
# 35063                                 0.0                 6926.0
#
#        generation fossil hard coal  generation fossil oil  \
# 35059                       2628.0                  178.0
# 35060                       2566.0                  174.0
# 35061                       2422.0                  168.0
# 35062                       2293.0                  163.0
# 35063                       2166.0                  163.0
#
#        generation fossil oil shale  generation fossil peat  \
# 35059                          0.0                     0.0
# 35060                          0.0                     0.0
# 35061                          0.0                     0.0
# 35062                          0.0                     0.0
# 35063                          0.0                     0.0
#
#        generation geothermal  ...  generation waste  generation wind offshore  \
# 35059                    0.0  ...             277.0                       0.0
# 35060                    0.0  ...             280.0                       0.0
# 35061                    0.0  ...             286.0                       0.0
# 35062                    0.0  ...             287.0                       0.0
# 35063                    0.0  ...             287.0                       0.0
#
#        generation wind onshore  forecast solar day ahead  \
# 35059                   3113.0                      96.0
# 35060                   3288.0                      51.0
# 35061                   3503.0                      36.0
# 35062                   3586.0                      29.0
# 35063                   3651.0                      26.0
#
#        forecast wind offshore eday ahead  forecast wind onshore day ahead  \
# 35059                                NaN                           3253.0
# 35060                                NaN                           3353.0
# 35061                                NaN                           3404.0
# 35062                                NaN                           3273.0
# 35063                                NaN                           3117.0
#
#        total load forecast  total load actual  price day ahead  price actual
# 35059              30619.0            30653.0            68.85         77.02
# 35060              29932.0            29735.0            68.40         76.16
# 35061              27903.0            28071.0            66.88         74.30
# 35062              25450.0            25801.0            63.93         69.89
# 35063              24424.0            24455.0            64.27         69.88
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Plot the target series
#
# Here we inspect a preview of the target time series column.

# %%
fig, axs = plt.subplots(len(target_columns), 1, figsize=(10, 2 * len(target_columns)), squeeze=False)
for ax, target_column in zip(axs, target_columns):
    ax[0].plot(input_df[timestamp_column], input_df[target_column])

# %% [markdown]
# ### Set up zero shot model
# The TTM model is hosted on [Hugging Face](https://huggingface.co/ibm-granite/granite-timeseries-ttm-v1), and is retrieved by the wrapper, `TinyTimeMixerForPrediction`. We have one input channel in this example.

# %%
# Instantiate the model.
zeroshot_model = TinyTimeMixerForPrediction.from_pretrained(
    "ibm-granite/granite-timeseries-ttm-r2",  # Name of the model on Hugging Face
    num_input_channels=len(target_columns),  # tsp.num_input_channels
)

# %% [markdown]
# ### Create a forecasting pipeline
#
# Set up the forecasting pipeline with the model, setting `frequency` given our knowledge of the sample frequency. In this example we set `explode_forecasts` to `False`, which keeps each sequence of predictions in a list within the dataframe cells. We then make a forecast on the dataset.

# %%
# Create a pipeline.
pipeline = TimeSeriesForecastingPipeline(
    zeroshot_model,
    timestamp_column=timestamp_column,
    id_columns=[],
    target_columns=target_columns,
    explode_forecasts=False,
    freq="h",
    device="cpu",  # Specify your local GPU or CPU.
)

# Make a forecast on the target column given the input data.
zeroshot_forecast = pipeline(input_df)
zeroshot_forecast.tail()
# Out:
# Device set to use cpu
#                        time  \
# 0 2018-12-31 23:00:00+01:00
#
#                         total load actual_prediction  \
# 0  [23465.3671875, 22127.962890625, 21162.0664062...
#
#                                    total load actual
# 0  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...

# %% [markdown]
# ### Plot predictions along with the historical data.
#
# The predicted series picks up where the historical data ends, and we can see that it predicts a continuation of the cyclical pattern and an upward trend.

# %%
# Plot the historical data and predicted series.
plot_predictions(
    input_df=input_df,
    predictions_df=zeroshot_forecast,
    freq="h",
    timestamp_column=timestamp_column,
    channel=target_column,
    indices=[-1],
    num_plots=1,
)
# Out:
# /Users/flaviajaninebeo/Documents/GitHub/granite-workshop/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:7588: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)
